# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_regression
from sklearn.metrics import r2_score , mean_absolute_error , mean_squared_error
import plotly.express as px
import plotly.graph_objects as go

# %%
x,y = make_regression(n_samples=100, n_features=2 , n_informative=2,n_targets=1,noise=50)

# %%
df = pd.DataFrame({'feature1':x[:,0],'feature2':x[:,1],'target':y})

# %%
df.head()
# Out:
#    feature1  feature2     target
# 0 -0.349694 -0.862908 -84.668529
# 1 -0.275435  0.411100 -42.613279
# 2 -0.567659  0.180789 -33.616811
# 3 -0.435811 -1.347744  23.309475
# 4  0.048981  0.213154 -11.296221

# %%
df.shape
# Out:
# (100, 3)

# %%
fig = px.scatter_3d(df , x='feature1' , y='feature2' , z='target')
fig.show()

# %%
from sklearn.model_selection import train_test_split 
x_train , x_test ,y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
print("MAE=",mean_absolute_error(y_pred,y_test))
print("MSE=" , mean_squared_error(y_pred,y_test))
print("R2=",r2_score(y_pred,y_test))
# Out:
# MAE= 41.885536684833035
# MSE= 2931.7099275655955
# R2= 0.4480317919378728

# %%
lr.coef_
# Out:
# array([59.54887482, 33.16923228])

# %%
lr.intercept_
# Out:
# np.float64(-0.6836089735312019)
